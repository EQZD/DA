# %% [markdown]
# 🔹 Part 1 – Data Understanding
#
#
# Tasks:
#
# 1) Show first 10 rows
#
# 2) Print column types
#
# 3) Show dataset size
#
# 4) Provide statistical summary
#
# 5) Identify categorical vs numerical columns
#
# Answer the questions:
# 6) Which columns look problematic?
#
# 7) Where might errors exist?
#
# 8) What information seems useless?

# %% [markdown]
# Part 2 – Data Quality Check
#
# Find:
#
# ✅ missing values \
# ✅ duplicates \
# ✅ strange values \
# ✅ outliers \
# ✅ inconsistent categories

# %% [markdown]
# 🔹 Part 3 – Missing Values Handling
#
# For each column with missing values:
#
# 1) Calculate percentage
#
# 2) Decide strategy
#
# 3) Explain WHY

# %% [markdown]
# Part 4 – Data Cleaning
#
#
# 1) fix categorical inconsistencies
#
# 2) rename columns if needed
#
# 3) convert data types
#
# 4) remove duplicates
#
# 5) create cleaner structure

# %% [markdown]
# Part 5 – Feature Engineering
#
# Create at least 3 new features.

# %% [markdown]
# Part 7 – Normalization
#
# Normalize at least 3 numerical features.

# %% [markdown]
# Part 8 - Anomalies
# Detect anomalies
